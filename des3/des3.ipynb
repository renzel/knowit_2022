# %%
import csv

with open("pakker.csv", "r") as f:
    csv_reader = csv.reader(f, delimiter=',')
    line_number = 0
    total_length = 0
    max_length = 110
    for row in csv_reader:
        if line_number != 0:
            print(row)
            smallest_number = 1000000
            bredde = int(row[0])
            høyde = int(row[1])
            lengde = int(row[2])
            use_this = 0
            longest_row = bredde

            if høyde * 2 + lengde * 2 <= max_length:
                if smallest_number > bredde + høyde:
                    smallest_number = bredde + høyde
                if smallest_number > bredde + lengde:
                    smallest_number = bredde + lengde
            if høyde * 2 + bredde * 2 <= max_length:
                if smallest_number > lengde + bredde:
                    smallest_number = bredde + lengde
                if smallest_number > lengde + høyde:
                    smallest_number = høyde + lengde
            if lengde * 2 + bredde * 2 <= max_length:
                if smallest_number > høyde + lengde:
                    smallest_number = høyde + lengde
                if smallest_number > høyde + bredde:
                    smallest_number = høyde + bredde
         
            if høyde + lengde <= max_length:
                if smallest_number > bredde*2 + lengde*2:
                    smallest_number = bredde*2 + lengde*2
                if smallest_number > bredde*2 + høyde*2:
                    smallest_number = bredde*2 + høyde*2
            if høyde + bredde <= max_length:
                if smallest_number > høyde*2 + lengde*2:
                    smallest_number = lengde*2 + høyde*2
                if smallest_number > bredde*2 + lengde*2:
                    smallest_number = bredde*2 + lengde*2
            if lengde + bredde <= max_length:
                if smallest_number > høyde*2 + lengde*2:
                    smallest_number = lengde*2 + høyde*2
                if smallest_number > bredde*2 + høyde*2:
                    smallest_number = bredde*2 + høyde*2
            print(smallest_number)
            total_length += smallest_number

           

        line_number += 1
print(total_length)
# Out:
# ['18', '36', '185']
# 203
# ['10', '62', '40']
# 72
# ['11', '30', '140']
# 151
# ['41', '22', '30']
# 63
# ['12', '17', '78']
# 58
# ['27', '55', '154']
# 362
# ['24', '20', '46']
# 66
# ['26', '36', '108']
# 268
# ['0', '32', '20']
# 20
# ['42', '24', '16']
# 58
# ['2', '27', '41']
# 29
# ['9', '21', '2']
# 11
# ['33', '30', '16']
# 46
# ['20', '23', '16']
# 36
# ['15', '58', '130']
# 290
# ['8', '18', '86']
# 52
# ['2', '67', '82']
# 138
# ['44', '14', '16']
# 58
# ['11', '43', '126']
# 137
# ['44', '21', '104']
# 250
# ['19', '29', '60']
# 79
# ['29', '24', '189']
# 213
# ['27', '3', '152']
# 155
# ['3', '70', '147']
# 300
# ['35', '30', '70']
# 130
# ['15', '24', '20']
# 35
# ['10', '1', '133']
# 134
# ['30', '39', '105']
# 270
# ['9', '6', '39']
# 15
# ['2', '70', '86']
# 144
# ['28', '50', '112']
# 280
# ['36', '33', '88']
# 242
# ['7', '68', '154']
# 322
# ['10', '40', '24']
# 34
# ['26', '20', '125']
# 145
# ['22', '51', '69']
# 146
# ['39', '24', '27']
# 63
# ...

# %%
oct(9)

# %%
55*2+27*2

# %%
import csv

with open("pakker.csv", "r") as f:
    csv_reader = csv.reader(f, delimiter=',')
    line_number = 0
    total_length = 0
    max_length = 110
    for row in csv_reader:
        if line_number != 0:
            print(row)
            smallest_number = 1000000
            row_0 = int(row[0])
            row_1 = int(row[1])
            row_2 = int(row[2])
            use_this = 0
            longest_row = row_0

            if row_1 > longest_row:
                longest_row = row_1
            if row_2 > longest_row:
                longest_row = row_2
            
            if row_1 * 2 + row_2 * 2 <= max_length:
                if smallest_number > row_0 + row_1:
                    smallest_number = row_0 + row_1
                if smallest_number > row_0 + row_2:
                    smallest_number = row_0 + row_2
            if row_1 * 2 + row_0 * 2 <= max_length:
                if smallest_number > row_2 + row_0:
                    smallest_number = row_0 + row_2
                if smallest_number > row_2 + row_1:
                    smallest_number = row_1 + row_2
            if row_2 * 2 + row_0 * 2 <= max_length:
                if smallest_number > row_1 + row_2:
                    smallest_number = row_1 + row_2
                if smallest_number > row_1 + row_0:
                    smallest_number = row_1 + row_0
           
            if smallest_number == 1000000:
                if row_0 == longest_row:
                    if row_1 > row_2:
                        if row_1*2 <= max_length:
                            print(row_0*2 + row_2*2)
                            total_length += row_0*2 + row_2*2
                        else:
                            print(row_0*2 + row_1*2)
                            total_length += row_0*2 + row_1*2
                    else:
                        print(row_0*2 + row_1*2)
                        total_length += row_0*2 + row_1*2
                elif row_1 == longest_row:
                    if row_2 > row_0:
                        if row_2*2 <= max_length:
                            print(row_1*2 + row_0*2)
                            total_length += row_1*2 + row_0*2
                        else:
                            print(row_1*2 + row_2*2)
                            total_length += row_1*2 + row_2*2
                    else:
                        print(row_1*2 + row_2*2)
                        total_length += row_1*2 + row_2*2
                elif row_2 == longest_row:
                    if row_1 > row_0:
                        if row_1*2 <= max_length:
                            print(row_2*2 + row_0*2)
                            total_length += row_2*2 + row_0*2
                        else:
                            print(row_2*2 + row_1*2)
                            total_length += row_2*2 + row_1*2
                    else:
                        print(row_2*2 + row_1*2)
                        total_length += row_2*2 + row_1*2
            
            else:
                print(f"use_this: {smallest_number}")
                total_length += smallest_number
            """elif use_this == 0:
                longest_row
                print(f"smallest_number: {smallest_number}")
                total_length += smallest_number"""

        line_number += 1
print(total_length)
